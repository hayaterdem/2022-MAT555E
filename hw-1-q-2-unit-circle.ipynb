# %% [markdown]
# <a href="https://www.kaggle.com/erdemhayat/hw-1-q-2-unit-circle?scriptVersionId=89403118" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# In mathematics, a unit circle is a circle of unit radius—that is, a radius of 1. Frequently, especially in trigonometry, the unit circle is the circle of radius 1 centered at the origin (0, 0) in the Cartesian coordinate system in the Euclidean plane. In topology, it is often denoted as S1 because it is a one-dimensional unit n-sphere.
# If (x, y) is a point on the unit circle's circumference, then |x| and |y| are the lengths of the legs of a right triangle whose hypotenuse has length 1. Thus, by the Pythagorean theorem, x and y satisfy the equation
# ![exp1.PNG](attachment:0ec0fed4-c5f1-4737-8011-15e65d0dafe6.PNG)
# Since ![exp3.PNG](attachment:962f927a-8c95-4088-af9b-6adb9751b43a.PNG) for all x, and since the reflection of any point on the unit circle about the x- or y-axis is also on the unit circle, the above equation holds for all points (x, y) on the unit circle, not only those in the first quadrant.
#
# The interior of the unit circle is called the open unit disk, while the interior of the unit circle combined with the unit circle itself is called the closed unit disk.
#
# One may also use other notions of "distance" to define other "unit circles", such as the Riemannian circle; see the article on mathematical norms for additional examples.
#
# ![exp2.PNG](attachment:b5d1bf86-ba6b-4992-bd9c-5aac752a12ce.PNG)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
figure, axes = plt.subplots()
draw_circle = plt.Circle((0, 0), 0.5,fill=False)
axes.set_aspect(1)
axes.add_artist(draw_circle)
plt.title('Unit Circle')
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.grid()
plt.show()

# %% [markdown]
# >Trigonometric functions on the unit circle
#
# The trigonometric functions cosine and sine of angle θ may be defined on the unit circle as follows: If (x, y) is a point on the unit circle, and if the ray from the origin (0, 0) to (x, y) makes an angle θ from the positive x-axis, (where counterclockwise turning is positive), then
# ![exp4.PNG](attachment:bf7db6d4-e7fa-4408-9e57-3e75f76de4a8.PNG)
# The equation ![exp1.PNG](attachment:18d9df28-2ac3-4c79-9b0b-8649090867ce.PNG) gives the relation
# ![exp5.PNG](attachment:7ad9870d-7568-40e8-a607-15f4000bfc39.PNG)
# The unit circle also demonstrates that sine and cosine are periodic functions, with the identities
# ![exp6.PNG](attachment:47f57928-2e8e-40bf-939e-de543a812aaa.PNG)
# for any integer k.

# %% [markdown]
# ![Circle](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Unitycircle-complex.gif/330px-Unitycircle-complex.gif)

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 100)

radius = 0.5

a = radius*np.cos(theta)
b = radius*np.sin(theta)

figure, axes = plt.subplots(1)

axes.plot(a, b)
axes.set_aspect(1)
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.grid()
plt.title('Unit Circle Using Parametric Equation')
plt.show()
