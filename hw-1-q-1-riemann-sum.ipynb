# %% [markdown]
# <a href="https://www.kaggle.com/erdemhayat/hw-1-q-1-riemann-sum?scriptVersionId=89598234" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# A Riemann sum of a function f(x) over a partition

# %% [markdown]
# ![download.png](attachment:ba4de5c1-0b4d-498b-977e-5299b449b47e.png)

# %% [markdown]
# It is sum of the form

# %% [markdown]
# ![exp2.PNG](attachment:d34ddc1d-6041-4b7f-bfaa-089b4b7a4758.PNG)

# %% [markdown]
# Where each value ![exp3.PNG](attachment:6a7fc09e-4fa8-4187-94ff-5b9ea3dc765b.PNG) in each subinterval is arbitrary.

# %% [markdown]
# Riemann sums are important because they provide an easy way to approximate a definite integral

# %% [markdown]
# ![exp4.PNG](attachment:61f1fe83-9313-4e30-b5bd-202f8e92f28e.PNG)

# %% [markdown]
# Notice that the product ![exp5.PNG](attachment:27cef3ba-c7a8-4f97-8701-004d4d76b002.PNG) for each i is the area of a rectangle of height ![exp6.PNG](attachment:6ccb14af-8f5d-4cf3-92d6-456871a49a12.PNG) and width ![exp7.PNG](attachment:4b1e1d9d-d98e-4bef-8adf-2f957af36236.PNG). We can think of a Riemann sum as the area of N rectangles with heights determined by the graph of y=f(x).

# %% [markdown]
# The value ![exp8.PNG](attachment:9adcd14a-e524-4c53-810b-4c1a5bb5640d.PNG)chosen in each subinterval is arbitrary however there are certain obvious choices:

# %% [markdown]
# - A left Riemann sum is when each ![exp9.PNG](attachment:021f6e61-09c1-4ba6-89d6-6661c9abbece.PNG) is the left endpoint of the subinterval ![exp10.PNG](attachment:41dbc091-6259-4c99-8d12-8ccdf674b392.PNG).

# %% [markdown]
# - A right Riemann sum is when each ![exp11.PNG](attachment:fd0bfc8d-5749-4137-813a-1b14a33b4f71.PNG) is the right endpoint of the subinterval ![exp10.PNG](attachment:b275994a-0f18-4e68-bfe6-26a25ccc0e0a.PNG).

# %% [markdown]
# - A midpoint Riemann sum is when each ![exp12.PNG](attachment:d969703d-b20a-4143-af12-bc5daa1c89f6.PNG) is the midpoint of the subinterval ![exp10.PNG](attachment:281926a6-f40c-4af3-9a3b-da50826cb06f.PNG).

# %% [markdown]
# Let's visualize rectangles in the left, right and midpoint Riemann sums for the function

# %% [markdown]
# ![exp13.PNG](attachment:bebc5a6e-667a-4b65-be2c-b20db69e235c.PNG) over the interval [0,5] with a partition of size N=10

# %%
f = lambda x : 1/(1+x**2)
a = 0; b = 5; N = 10
n = 10 # Use n*N+1 points to plot the function smoothly

x = np.linspace(a,b,N+1) #Create an array that limited a and b, divided by N+1 with equal intervals 
y = f(x)

X = np.linspace(a,b,n*N+1)
Y = f(X)

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(X,Y,'b')
x_left = x[:-1] # Left endpoints
y_left = y[:-1]
plt.plot(x_left,y_left,'b.',markersize=10)
plt.bar(x_left,y_left,width=(b-a)/N,alpha=0.2,align='edge',edgecolor='b')
plt.title('Left Riemann Sum, N = {}'.format(N))

plt.subplot(1,3,2)
plt.plot(X,Y,'b')
x_mid = (x[:-1] + x[1:])/2 # Midpoints
y_mid = f(x_mid)
plt.plot(x_mid,y_mid,'b.',markersize=10)
plt.bar(x_mid,y_mid,width=(b-a)/N,alpha=0.2,edgecolor='b')
plt.title('Midpoint Riemann Sum, N = {}'.format(N))

plt.subplot(1,3,3)
plt.plot(X,Y,'b')
x_right = x[1:] # Left endpoints
y_right = y[1:]
plt.plot(x_right,y_right,'b.',markersize=10)
plt.bar(x_right,y_right,width=-(b-a)/N,alpha=0.2,align='edge',edgecolor='b')
plt.title('Right Riemann Sum, N = {}'.format(N))

plt.show()

# %% [markdown]
# Notice that when the function f(x) is decreasing on [a,b]  the left endpoints give an overestimate of the integral ![exp14.PNG](attachment:2f6575ff-81c6-4cd0-b281-d62d81b3e620.PNG) and right endpoints give an underestimate. The opposite is true is when the function is increasing.
#
# Let's compute the value of each of the Riemann sums:

# %%
dx = (b-a)/N
x_left = np.linspace(a,b-dx,N)
x_midpoint = np.linspace(dx/2,b - dx/2,N)
x_right = np.linspace(dx,b,N)

print("Partition with",N,"subintervals.")
left_riemann_sum = np.sum(f(x_left) * dx)
print("Left Riemann Sum:",left_riemann_sum)

midpoint_riemann_sum = np.sum(f(x_midpoint) * dx)
print("Midpoint Riemann Sum:",midpoint_riemann_sum)

right_riemann_sum = np.sum(f(x_right) * dx)
print("Right Riemann Sum:",right_riemann_sum)
# Out:
# Partition with 10 subintervals.
# Left Riemann Sum: 1.613488696614725
# Midpoint Riemann Sum: 1.373543428316664
# Right Riemann Sum: 1.1327194658454942

# %% [markdown]
# We know the exact value
# ![exp15.PNG](attachment:fde88ba6-2011-466f-a249-b4f04e1e4c93.PNG)
# and we can compare the Riemann sums to the value

# %%
I = np.arctan(5)
print(I)
# Out:
# 1.373400766945016

# %%
print("Left Riemann Sum Error:",np.abs(left_riemann_sum - I))
print("Midpoint Riemann Sum:",np.abs(midpoint_riemann_sum - I))
print("Right Riemann Sum:",np.abs(right_riemann_sum - I))
# Out:
# Left Riemann Sum Error: 0.24008792966970915
# Midpoint Riemann Sum: 0.00014266137164820059
# Right Riemann Sum: 0.24068130109952168
